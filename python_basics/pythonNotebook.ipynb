# %% [markdown]
# # What is Python Language?

# %% [markdown]
# ## Python is the programming Language, which we can use for communicating with computers or technology

# %% [markdown]
# # Syntax for the Python Language?

# %% [markdown]
# ## Syntax refers to the set of rules that defines the combination of symbols that are considered to be correctly structured programms in a language.

# %% [markdown]
# # Symantics of Python Language?

# %% [markdown]
# ## Symantics of Python Language referes to the meaning or interpetitions of symbols, characters and comments in a language. It is about what the code is soppose to do when it runs.

# %% [markdown]
# # Python Syntax rules?

# %% [markdown]
# ## 1. Python is Case senstive.

# %%
name = "Neeraj"
Name = "Neeraj"
name==Name
# Out:
# True

# %%
name = "NEERAJ"
Name = "Neeraj"         
name==Name
# Out:
# False

# %% [markdown]
# ## 2. Indentation in Python.

# %% [markdown]
# In Other Programming language we use braces {} for groupping of statement, but in python we use indentation for proper groupping of statements as the proper arrangement of statements with proper spacing in the statements within a block.

# %%
age = int(input("Enter your age: "))
if age > 18:
    print("You are eligible for driving license")
# Out:
# You are eligible for driving license

# %%
age = int(input("Enter your age: "))
if age > 18:
print("You are eligible for driving license")
# Out:
#   Cell In[4], line 3
#     print("You are eligible for driving license")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
a = 2+3+4+5+6+\
    7+8+9+10    
print(a)
# Out:
# 54

# %%
5+6+7+9+8+4+6+\
    7+8+9+10
# Out:
# 79

# %% [markdown]
# > Here Back Slash'\' is used as the line continuation

# %% [markdown]
# >We can write Multiple statements in single line

# %%
a=32;
b=29;
a+b
# Out:
# 61

# %%
a= 24 b= 29
a+b
# Out:
#   Cell In[16], line 1
#     a= 24 b= 29
#           ^
# SyntaxError: invalid syntax

# %%
a=24; b=29
a+b
# Out:
# 53
