# %% [markdown]
# # Keywords

# %% [markdown]
# #### Keywords are the reserved words that have predefined meaning and specific functonality within the language syntax.
# #### Keywords cannot be used as name variable, functions or any other identifiers as doing so will confuse the interpreter.
# #### They are built-in vocabulary that Python use to understand the structure of your code.

# %% [markdown]
# ## Keywords are:
#
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)
