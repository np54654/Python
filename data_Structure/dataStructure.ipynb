# %% [markdown]
# # Data Structures in Python

# %% [markdown]
# #### Data structures in Python are being used for storing the data in a structuresd format, so that we can access the data and along with that we can perform all of the operations with these data structures that we can perform in a case of database as well, like CRUDE operations (Create, Read, Update, Delete).

# %% [markdown]
# ## Types of Data Structure in Python are:
# #### The different type of data structure differs on the basis of how we want to store our data.
#
# #### 1. List
# #### List are one of the type of data structures which are used for storing the data in the structured format where you can store data of any data type and that it is one of the data structure so we can have the access of the data as well that we are going to stroe into the list and we can apply CRUD operations as well i.e. Create, Read, Update, Delete operations as well.
#
# #### 2. Tuple
# #### 3. Set
# #### 4. Dictionary
